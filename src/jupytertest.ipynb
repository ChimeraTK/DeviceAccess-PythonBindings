# %%
from _da_python_bindings import *

# %%
import numpy as np

# %%
setDMapFilePath("/home/cwillner/software/sources/ChimeraTK-DeviceAccess-PythonBindings/tests/deviceInformation/exampleCrate.dmap")
dev = Device("CARD_WITH_MODULES")
dev.open()

# %%
oneDacc = dev.getOneDRegisterAccessor(np.dtype("float32"), 'BOARD/WORD_CLK_MUX')
scalaracc = dev.getScalarRegisterAccessor(np.dtype("int32"), 'BOARD/WORD_CLK_MUX')

# %%
scalaracc.set([2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 scalaracc.set([2])
#
# TypeError: set(): incompatible function arguments. The following argument types are supported:
#     1. (self: _da_python_bindings.ScalarRegisterAccessor, val: Union[ChimeraTK::Boolean, int, int, int, int, int, int, int, int, float, float, str]) -> None
#
# Invoked with: <repr raised Error>, [2]
